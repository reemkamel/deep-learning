# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    # xnorm = x - minval/maxval-minval
    minval = 0
    maxval = 255
    xnorm = (x - minval)/(maxval-minval)
    return xnorm


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    nb_classes = 10
    #targets = np.array(x).reshape(-1)
    one_hot = np.eye(nb_classes)[x]
    return one_hot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # tf Graph input
    x = tf.placeholder(tf.float32, [None] + list(image_shape), "x")
    return x

def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    y = tf.placeholder(tf.float32,[None, n_classes], "y")
    return y
    

def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    keep_prob = tf.placeholder(tf.float32,None, "keep_prob")
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # Create the weight and bias using conv_ksize, conv_num_outputs and the shape of x_tensor.
    x_dim = x_tensor.get_shape().as_list()
    
    # (height, width, input_depth, output_depth)
    layer_1_weight_shape = list(conv_ksize) + [x_dim[-1]] + [conv_num_outputs]
    W = tf.Variable(tf.truncated_normal(layer_1_weight_shape, stddev=0.1))
    # b = tf.Variable(tf.random_normal([conv_num_outputs]))
    b = tf.Variable(tf.zeros([conv_num_outputs]))
    
    # Apply a convolution to x_tensor using weight and conv_strides
    # stride (batch, height, width, depth)
    cv1 = tf.nn.conv2d(
        x_tensor, 
        W, 
        strides=[1] + list(conv_strides) + [1], 
        padding='SAME')
    cv1 = tf.nn.bias_add(cv1, b)
    cv1 = tf.nn.relu(cv1)
    cv1 = tf.nn.max_pool(
        cv1,
        ksize=[1] + list(pool_ksize) + [1],
        strides=[1] + list(pool_strides) + [1],
        padding='SAME')
    
    return cv1


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    x_dim = x_tensor.get_shape().as_list()
    # print(x_dim[1:])
    # to elminate None we will start from second element 
    # Batch Size x Image width x image height
    flatten_layer = tf.reshape(x_tensor, [-1, np.prod(x_dim[1:])])
    return flatten_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    x_dim = x_tensor.get_shape().as_list()
    # print(x_dim)
    # Weight and bias
    layer_2_weight_shape = [x_dim[-1]] + [num_outputs]
    
    weight = tf.Variable(tf.truncated_normal(layer_2_weight_shape,stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))

    # Apply Convolution
    conv_layer = tf.matmul(x_tensor, weight)
    # Add bias
    conv_layer = tf.add(conv_layer, bias)
    # Apply activation function
    conv_layer = tf.nn.relu(conv_layer)
    return conv_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Output Layer 
    x_dim = x_tensor.get_shape().as_list()
    # print(x_dim)
    # Weight and bias
    out_weight_shape = [x_dim[-1]] + [num_outputs]
    
    weight = tf.Variable(tf.truncated_normal(out_weight_shape,stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))

    # Apply Convolution
    out = tf.matmul(x_tensor, weight)
    # Add bias
    out = tf.add(out, bias)
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    
    #first trial valid accuracy didnt pass the 0.511600
    """
    conv_num_outputs = 16
    conv_ksize = [4,4] 
    conv_strides = [1,1]
    pool_ksize = [8,8]
    pool_strides = [1,1]
    """
    
    #second trial valid accuracy didnt pass the 0.491400
    """
    conv_num_outputs = 32
    conv_ksize = [5,5] 
    conv_strides = [1,1]
    pool_ksize = [3,3]
    pool_strides = [1,1]
    """
    
    #valid accuracy
    # with output 32 and changing pool size
    #[3,3] 0.528200
    #[4,4] 0.542000
    #[5,5] 0.547200
    #then decrease the output to 16 , increase pool size to 8 and decrease conv to 4
    # accuracy reached 0.597000
    #"""
    conv_num_outputs = 16 
    conv_ksize = [4,4] #it seems it should be less than pool size to exceed the .52
    conv_strides = [1,1]
    pool_ksize = [8,8]# several trials 
    pool_strides = [1,1]
    #"""
    
    model = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    model = flatten(model)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    """
    I started by 64 but accuracy didnt exceed .105 until I reached 256 and more
    320 --> 0.528400
    384 --> 0.538600 then I started to enhance in the first layer again
    """
    num_outputs = 384
    model = fully_conn(model, num_outputs)
    model = tf.nn.dropout(model, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    num_outputs = 10
    model = output(model, num_outputs)
    
    
    return model
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # Calculate batch loss and accuracy
    loss = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.})
    valid_acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.})

    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
        loss,
        valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = .5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2298 Validation Accuracy: 0.205200
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.1103 Validation Accuracy: 0.281000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.9721 Validation Accuracy: 0.317200
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.8529 Validation Accuracy: 0.373000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.7277 Validation Accuracy: 0.416600
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.6184 Validation Accuracy: 0.440600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.5526 Validation Accuracy: 0.463800
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.4691 Validation Accuracy: 0.486200
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.4353 Validation Accuracy: 0.490200
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.3723 Validation Accuracy: 0.502400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.3230 Validation Accuracy: 0.517200
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.2799 Validation Accuracy: 0.523400
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.2653 Validation Accuracy: 0.525600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.2237 Validation Accuracy: 0.529200
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.1967 Validation Accuracy: 0.530600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.1720 Validation Accuracy: 0.540000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.1411 Validation Accuracy: 0.536200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.1227 Validation Accuracy: 0.544000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.1098 Validation Accuracy: 0.540600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.0941 Validation Accuracy: 0.547000
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.0439 Validation Accuracy: 0.554600
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.0418 Validation Accuracy: 0.552600
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.0061 Validation Accuracy: 0.559600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.0016 Validation Accuracy: 0.554200
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.9691 Validation Accuracy: 0.559200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.9619 Validation Accuracy: 0.562800
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.9343 Validation Accuracy: 0.561600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.9433 Validation Accuracy: 0.562600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.9267 Validation Accuracy: 0.565200
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.9036 Validation Accuracy: 0.566000
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.8731 Validation Accuracy: 0.567000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.8654 Validation Accuracy: 0.572200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.8334 Validation Accuracy: 0.572600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.8366 Validation Accuracy: 0.571200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.8103 Validation Accuracy: 0.572800
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.8064 Validation Accuracy: 0.576400
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.7994 Validation Accuracy: 0.575200
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.7996 Validation Accuracy: 0.572800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.7829 Validation Accuracy: 0.579200
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.7623 Validation Accuracy: 0.583800
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.7409 Validation Accuracy: 0.577000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.7305 Validation Accuracy: 0.574200
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.7186 Validation Accuracy: 0.579600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.6878 Validation Accuracy: 0.578800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.6846 Validation Accuracy: 0.586400
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.6788 Validation Accuracy: 0.579600
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.6759 Validation Accuracy: 0.583400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.6767 Validation Accuracy: 0.586600
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.6414 Validation Accuracy: 0.585000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.6338 Validation Accuracy: 0.591400
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.6561 Validation Accuracy: 0.580000
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.6631 Validation Accuracy: 0.583800
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.6344 Validation Accuracy: 0.579600
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.6105 Validation Accuracy: 0.586600
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.5927 Validation Accuracy: 0.596400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.5917 Validation Accuracy: 0.592800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.5798 Validation Accuracy: 0.591800
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.5841 Validation Accuracy: 0.591400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.5760 Validation Accuracy: 0.588800
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.5641 Validation Accuracy: 0.590000
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.5506 Validation Accuracy: 0.589600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.5548 Validation Accuracy: 0.583200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.5485 Validation Accuracy: 0.592800
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.5386 Validation Accuracy: 0.589000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.5519 Validation Accuracy: 0.585000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.5761 Validation Accuracy: 0.581000
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.5682 Validation Accuracy: 0.581000
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.5486 Validation Accuracy: 0.586800
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.5167 Validation Accuracy: 0.593600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.5055 Validation Accuracy: 0.589400
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.5056 Validation Accuracy: 0.589000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.5448 Validation Accuracy: 0.587600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.5446 Validation Accuracy: 0.579600
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.5413 Validation Accuracy: 0.582200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.5007 Validation Accuracy: 0.588000
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.5019 Validation Accuracy: 0.586800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.4698 Validation Accuracy: 0.594000
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.4496 Validation Accuracy: 0.592400
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.4527 Validation Accuracy: 0.593400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.4637 Validation Accuracy: 0.592000
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.4626 Validation Accuracy: 0.591200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.4063 Validation Accuracy: 0.593000
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.4206 Validation Accuracy: 0.597600
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.4033 Validation Accuracy: 0.594200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.4251 Validation Accuracy: 0.592000
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.4583 Validation Accuracy: 0.582600
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.4164 Validation Accuracy: 0.593400
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.4119 Validation Accuracy: 0.596000
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.3777 Validation Accuracy: 0.595800
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.4029 Validation Accuracy: 0.592000
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.4052 Validation Accuracy: 0.589400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.4036 Validation Accuracy: 0.593000
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.3923 Validation Accuracy: 0.590800
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.3923 Validation Accuracy: 0.588400
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.3843 Validation Accuracy: 0.587400
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.3831 Validation Accuracy: 0.587000
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.3733 Validation Accuracy: 0.592000
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.3732 Validation Accuracy: 0.590200
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.3377 Validation Accuracy: 0.597400
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.3453 Validation Accuracy: 0.597200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.1227 Validation Accuracy: 0.246200
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.8526 Validation Accuracy: 0.335600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.6422 Validation Accuracy: 0.401400
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.5728 Validation Accuracy: 0.426600
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.5386 Validation Accuracy: 0.453400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.5510 Validation Accuracy: 0.487400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.3504 Validation Accuracy: 0.499600
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.2875 Validation Accuracy: 0.513200
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.2428 Validation Accuracy: 0.526000
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.2997 Validation Accuracy: 0.529000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.3501 Validation Accuracy: 0.535800
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.2269 Validation Accuracy: 0.536600
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.1476 Validation Accuracy: 0.554400
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.1236 Validation Accuracy: 0.555400
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.1685 Validation Accuracy: 0.565400
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.2089 Validation Accuracy: 0.568800
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.1471 Validation Accuracy: 0.565600
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.0266 Validation Accuracy: 0.580400
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.0206 Validation Accuracy: 0.578000
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.0610 Validation Accuracy: 0.583600
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.1461 Validation Accuracy: 0.588600
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.0837 Validation Accuracy: 0.588200
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.9836 Validation Accuracy: 0.593000
# Epoch  5, CIFAR-10 Batch 4:  Loss:     0.9708 Validation Accuracy: 0.598000
# Epoch  5, CIFAR-10 Batch 5:  Loss:     0.9798 Validation Accuracy: 0.590800
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.0856 Validation Accuracy: 0.600600
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.0411 Validation Accuracy: 0.599000
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.9156 Validation Accuracy: 0.606800
# Epoch  6, CIFAR-10 Batch 4:  Loss:     0.9219 Validation Accuracy: 0.610000
# Epoch  6, CIFAR-10 Batch 5:  Loss:     0.9214 Validation Accuracy: 0.610800
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.0650 Validation Accuracy: 0.597200
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.0169 Validation Accuracy: 0.602000
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.8482 Validation Accuracy: 0.620600
# Epoch  7, CIFAR-10 Batch 4:  Loss:     0.9075 Validation Accuracy: 0.619800
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.8693 Validation Accuracy: 0.620200
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.9905 Validation Accuracy: 0.612400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.9439 Validation Accuracy: 0.620000
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.8256 Validation Accuracy: 0.630200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.8387 Validation Accuracy: 0.634600
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.8378 Validation Accuracy: 0.631600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.9430 Validation Accuracy: 0.627000
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.9295 Validation Accuracy: 0.631600
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.7738 Validation Accuracy: 0.635400
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.8104 Validation Accuracy: 0.634600
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.7810 Validation Accuracy: 0.638000
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.9081 Validation Accuracy: 0.632800
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.8881 Validation Accuracy: 0.634000
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.7807 Validation Accuracy: 0.634000
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.8090 Validation Accuracy: 0.638800
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.7564 Validation Accuracy: 0.647200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.9056 Validation Accuracy: 0.630200
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.8706 Validation Accuracy: 0.637000
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.7464 Validation Accuracy: 0.650800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.7586 Validation Accuracy: 0.644800
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.7287 Validation Accuracy: 0.643800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.8726 Validation Accuracy: 0.638200
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.8278 Validation Accuracy: 0.648200
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.7175 Validation Accuracy: 0.647000
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.7420 Validation Accuracy: 0.648400
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.7146 Validation Accuracy: 0.656800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.8340 Validation Accuracy: 0.650000
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.8093 Validation Accuracy: 0.641200
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.7198 Validation Accuracy: 0.652000
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.7447 Validation Accuracy: 0.649200
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.6688 Validation Accuracy: 0.652800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.8091 Validation Accuracy: 0.655400
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.7964 Validation Accuracy: 0.650800
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.6677 Validation Accuracy: 0.655000
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.7044 Validation Accuracy: 0.661200
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.6638 Validation Accuracy: 0.661800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.7828 Validation Accuracy: 0.655600
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.7605 Validation Accuracy: 0.665400
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.6477 Validation Accuracy: 0.649400
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.6666 Validation Accuracy: 0.669000
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.6494 Validation Accuracy: 0.657600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.7724 Validation Accuracy: 0.651800
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.7745 Validation Accuracy: 0.651200
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.6485 Validation Accuracy: 0.663600
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.6772 Validation Accuracy: 0.670600
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.6076 Validation Accuracy: 0.669800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.7415 Validation Accuracy: 0.657600
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.7458 Validation Accuracy: 0.658000
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.6241 Validation Accuracy: 0.665600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.6482 Validation Accuracy: 0.670400
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.5823 Validation Accuracy: 0.677000
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.7200 Validation Accuracy: 0.660800
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.7194 Validation Accuracy: 0.664800
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.6137 Validation Accuracy: 0.667400
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.6325 Validation Accuracy: 0.672400
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.5689 Validation Accuracy: 0.670200
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.7050 Validation Accuracy: 0.650000
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.7188 Validation Accuracy: 0.660800
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.6093 Validation Accuracy: 0.666000
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.6146 Validation Accuracy: 0.674400
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.5578 Validation Accuracy: 0.668400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.6789 Validation Accuracy: 0.663000
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.6780 Validation Accuracy: 0.662400
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.5833 Validation Accuracy: 0.672600
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.5817 Validation Accuracy: 0.676600
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.5320 Validation Accuracy: 0.678200
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.6559 Validation Accuracy: 0.672000
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.6452 Validation Accuracy: 0.672200
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.5859 Validation Accuracy: 0.668400
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.5917 Validation Accuracy: 0.673000
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.5146 Validation Accuracy: 0.677400
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.6661 Validation Accuracy: 0.672600
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.6350 Validation Accuracy: 0.678000
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.5679 Validation Accuracy: 0.667400
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.5656 Validation Accuracy: 0.674600
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.5005 Validation Accuracy: 0.674000
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.6398 Validation Accuracy: 0.672000
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.6231 Validation Accuracy: 0.672200
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.5517 Validation Accuracy: 0.670400
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.5400 Validation Accuracy: 0.680600
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.4932 Validation Accuracy: 0.672800
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.6423 Validation Accuracy: 0.671400
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.6006 Validation Accuracy: 0.679800
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.5087 Validation Accuracy: 0.680800
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.5528 Validation Accuracy: 0.678400
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.4825 Validation Accuracy: 0.684400
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.6053 Validation Accuracy: 0.671200
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.6092 Validation Accuracy: 0.676800
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.5348 Validation Accuracy: 0.666800
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.5215 Validation Accuracy: 0.682400
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.4780 Validation Accuracy: 0.672800
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.6037 Validation Accuracy: 0.667200
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.5853 Validation Accuracy: 0.675200
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.5011 Validation Accuracy: 0.678600
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.5120 Validation Accuracy: 0.687000
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.4567 Validation Accuracy: 0.684400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.5858 Validation Accuracy: 0.680200
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.5549 Validation Accuracy: 0.681600
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.4937 Validation Accuracy: 0.680800
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.5048 Validation Accuracy: 0.682600
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.4475 Validation Accuracy: 0.690400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.6024 Validation Accuracy: 0.675800
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.5513 Validation Accuracy: 0.679200
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.5008 Validation Accuracy: 0.678200
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.4940 Validation Accuracy: 0.684600
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.4434 Validation Accuracy: 0.682200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.5371 Validation Accuracy: 0.685000
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.5212 Validation Accuracy: 0.686200
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.4815 Validation Accuracy: 0.678600
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.4775 Validation Accuracy: 0.681800
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.4168 Validation Accuracy: 0.682600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.5297 Validation Accuracy: 0.674000
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.4983 Validation Accuracy: 0.681600
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.4755 Validation Accuracy: 0.678200
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.4956 Validation Accuracy: 0.679800
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.4174 Validation Accuracy: 0.688200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.5271 Validation Accuracy: 0.677200
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.4930 Validation Accuracy: 0.687600
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.4542 Validation Accuracy: 0.681600
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.4442 Validation Accuracy: 0.688200
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.3837 Validation Accuracy: 0.694000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.5386 Validation Accuracy: 0.671400
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.4904 Validation Accuracy: 0.692000
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.4510 Validation Accuracy: 0.672600
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.4532 Validation Accuracy: 0.684000
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.3954 Validation Accuracy: 0.689600
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.4911 Validation Accuracy: 0.679000
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.4864 Validation Accuracy: 0.688400
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.4482 Validation Accuracy: 0.680800
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.4461 Validation Accuracy: 0.683800
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.3687 Validation Accuracy: 0.684400
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.4663 Validation Accuracy: 0.686600
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.4798 Validation Accuracy: 0.689600
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.4279 Validation Accuracy: 0.679200
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.4362 Validation Accuracy: 0.685800
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.3916 Validation Accuracy: 0.682000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.5051 Validation Accuracy: 0.664200
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.4864 Validation Accuracy: 0.681400
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.4259 Validation Accuracy: 0.681200
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.4272 Validation Accuracy: 0.680200
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.3620 Validation Accuracy: 0.683800
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.4592 Validation Accuracy: 0.679000
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.4470 Validation Accuracy: 0.691200
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.4211 Validation Accuracy: 0.674600
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.4412 Validation Accuracy: 0.682200
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.3713 Validation Accuracy: 0.689000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.4946 Validation Accuracy: 0.669800
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.4576 Validation Accuracy: 0.686400
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.3831 Validation Accuracy: 0.684400
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.4156 Validation Accuracy: 0.680400
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.3374 Validation Accuracy: 0.685000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.4597 Validation Accuracy: 0.673600
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.4334 Validation Accuracy: 0.690600
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.3927 Validation Accuracy: 0.680800
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.4087 Validation Accuracy: 0.685600
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.3441 Validation Accuracy: 0.683800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.4651 Validation Accuracy: 0.680400
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.4260 Validation Accuracy: 0.683000
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.3779 Validation Accuracy: 0.687200
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.3990 Validation Accuracy: 0.680800
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.3423 Validation Accuracy: 0.686000
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.4160 Validation Accuracy: 0.688200
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.4050 Validation Accuracy: 0.692000
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.3694 Validation Accuracy: 0.682800
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.3897 Validation Accuracy: 0.681600
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.3267 Validation Accuracy: 0.691400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.4308 Validation Accuracy: 0.682800
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.3942 Validation Accuracy: 0.689200
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.3505 Validation Accuracy: 0.686800
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.3889 Validation Accuracy: 0.684000
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.3123 Validation Accuracy: 0.685000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.4297 Validation Accuracy: 0.677000
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.4110 Validation Accuracy: 0.683000
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.3554 Validation Accuracy: 0.686200
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.3818 Validation Accuracy: 0.688800
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.3257 Validation Accuracy: 0.685000
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.4402 Validation Accuracy: 0.686200
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.3763 Validation Accuracy: 0.691000
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.3294 Validation Accuracy: 0.693400
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.3932 Validation Accuracy: 0.684000
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.3186 Validation Accuracy: 0.689000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.3952 Validation Accuracy: 0.682400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.3725 Validation Accuracy: 0.687000
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.3435 Validation Accuracy: 0.682000
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.3519 Validation Accuracy: 0.688600
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.2983 Validation Accuracy: 0.689000
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.4024 Validation Accuracy: 0.681600
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.3471 Validation Accuracy: 0.694800
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.3268 Validation Accuracy: 0.681200
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.3519 Validation Accuracy: 0.688200
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.2898 Validation Accuracy: 0.686800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.3953 Validation Accuracy: 0.683400
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.3629 Validation Accuracy: 0.691200
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.3260 Validation Accuracy: 0.682200
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.3717 Validation Accuracy: 0.676400
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.2861 Validation Accuracy: 0.684600
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.3957 Validation Accuracy: 0.690600
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.3515 Validation Accuracy: 0.683400
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.3305 Validation Accuracy: 0.688200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.3393 Validation Accuracy: 0.689000
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.2896 Validation Accuracy: 0.685200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.3847 Validation Accuracy: 0.687400
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.3435 Validation Accuracy: 0.692400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.3178 Validation Accuracy: 0.683800
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.3484 Validation Accuracy: 0.684600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.2772 Validation Accuracy: 0.690600
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.3865 Validation Accuracy: 0.678200
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.3277 Validation Accuracy: 0.692600
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.3002 Validation Accuracy: 0.687400
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.3403 Validation Accuracy: 0.680400
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.2623 Validation Accuracy: 0.691000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.3654 Validation Accuracy: 0.686000
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.3313 Validation Accuracy: 0.683000
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.3221 Validation Accuracy: 0.681200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.3374 Validation Accuracy: 0.682200
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.2564 Validation Accuracy: 0.683000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.3447 Validation Accuracy: 0.690000
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.3220 Validation Accuracy: 0.685600
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.2990 Validation Accuracy: 0.683000
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.3180 Validation Accuracy: 0.682800
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.2531 Validation Accuracy: 0.683600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.3648 Validation Accuracy: 0.683200
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.3196 Validation Accuracy: 0.685400
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.2845 Validation Accuracy: 0.683800
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.2996 Validation Accuracy: 0.687600
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.2649 Validation Accuracy: 0.688400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.3440 Validation Accuracy: 0.690400
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.3316 Validation Accuracy: 0.685800
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.2968 Validation Accuracy: 0.682200
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.3366 Validation Accuracy: 0.680200
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.2260 Validation Accuracy: 0.690200
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.3646 Validation Accuracy: 0.679000
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.3574 Validation Accuracy: 0.682600
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.2786 Validation Accuracy: 0.681800
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.3130 Validation Accuracy: 0.686200
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.2422 Validation Accuracy: 0.686400
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.3495 Validation Accuracy: 0.680000
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.2957 Validation Accuracy: 0.682000
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.2671 Validation Accuracy: 0.683400
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.2823 Validation Accuracy: 0.688400
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.2472 Validation Accuracy: 0.684400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.3334 Validation Accuracy: 0.682400
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.3504 Validation Accuracy: 0.683400
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.2881 Validation Accuracy: 0.675600
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.3053 Validation Accuracy: 0.680400
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.2591 Validation Accuracy: 0.684000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.3262 Validation Accuracy: 0.688800
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.2987 Validation Accuracy: 0.690600
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.2725 Validation Accuracy: 0.683400
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.3055 Validation Accuracy: 0.686600
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.2229 Validation Accuracy: 0.687600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.3231 Validation Accuracy: 0.685200
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.2870 Validation Accuracy: 0.687000
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.2489 Validation Accuracy: 0.689400
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.2876 Validation Accuracy: 0.684600
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.2258 Validation Accuracy: 0.689200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.3136 Validation Accuracy: 0.687200
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.3043 Validation Accuracy: 0.684800
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.2774 Validation Accuracy: 0.685000
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.3235 Validation Accuracy: 0.675200
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.2405 Validation Accuracy: 0.686400
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.2996 Validation Accuracy: 0.692200
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.2829 Validation Accuracy: 0.681000
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.2369 Validation Accuracy: 0.692600
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.2694 Validation Accuracy: 0.681400
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.2427 Validation Accuracy: 0.683400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.2806 Validation Accuracy: 0.685800
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.2778 Validation Accuracy: 0.683800
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.2555 Validation Accuracy: 0.681200
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.2869 Validation Accuracy: 0.674000
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.2144 Validation Accuracy: 0.689600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.2764 Validation Accuracy: 0.683200
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.2727 Validation Accuracy: 0.684000
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.2379 Validation Accuracy: 0.690800
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.2769 Validation Accuracy: 0.681200
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.1990 Validation Accuracy: 0.689600
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.2921 Validation Accuracy: 0.691600
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.2640 Validation Accuracy: 0.679400
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.2097 Validation Accuracy: 0.687000
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.2644 Validation Accuracy: 0.688000
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.2160 Validation Accuracy: 0.684800
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.2740 Validation Accuracy: 0.686200
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.2708 Validation Accuracy: 0.689000
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.2197 Validation Accuracy: 0.692200
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.2558 Validation Accuracy: 0.687000
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.1836 Validation Accuracy: 0.685400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.2749 Validation Accuracy: 0.686200
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.2345 Validation Accuracy: 0.693200
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.2116 Validation Accuracy: 0.687800
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.2425 Validation Accuracy: 0.682600
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.1801 Validation Accuracy: 0.689400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.2421 Validation Accuracy: 0.685200
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.2668 Validation Accuracy: 0.676400
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.2164 Validation Accuracy: 0.681600
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.2644 Validation Accuracy: 0.681600
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.2076 Validation Accuracy: 0.686600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.2557 Validation Accuracy: 0.686000
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.2497 Validation Accuracy: 0.685600
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.1953 Validation Accuracy: 0.686000
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.2462 Validation Accuracy: 0.682400
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.1872 Validation Accuracy: 0.680200
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.2513 Validation Accuracy: 0.689200
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.2421 Validation Accuracy: 0.683400
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.1919 Validation Accuracy: 0.686400
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.2328 Validation Accuracy: 0.687400
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.1785 Validation Accuracy: 0.686200
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.2579 Validation Accuracy: 0.693600
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.2243 Validation Accuracy: 0.682400
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.2171 Validation Accuracy: 0.683200
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.2357 Validation Accuracy: 0.677800
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.1895 Validation Accuracy: 0.681400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.2436 Validation Accuracy: 0.691000
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.2260 Validation Accuracy: 0.690200
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.1800 Validation Accuracy: 0.686000
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.2166 Validation Accuracy: 0.680000
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.1811 Validation Accuracy: 0.691600
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.2291 Validation Accuracy: 0.682800
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.2169 Validation Accuracy: 0.686200
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.1752 Validation Accuracy: 0.689400
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.2114 Validation Accuracy: 0.679000
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.1620 Validation Accuracy: 0.678000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.2381 Validation Accuracy: 0.687000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.2222 Validation Accuracy: 0.678600
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.2068 Validation Accuracy: 0.681400
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.2238 Validation Accuracy: 0.675600
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.1555 Validation Accuracy: 0.687600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.2442 Validation Accuracy: 0.689200
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.2150 Validation Accuracy: 0.691800
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.1871 Validation Accuracy: 0.684400
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.2253 Validation Accuracy: 0.677800
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.1583 Validation Accuracy: 0.689400
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.2365 Validation Accuracy: 0.685800
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.1998 Validation Accuracy: 0.687600
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.1786 Validation Accuracy: 0.682600
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.2139 Validation Accuracy: 0.685200
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.1530 Validation Accuracy: 0.687400
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.2155 Validation Accuracy: 0.686400
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.1898 Validation Accuracy: 0.691800
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.1810 Validation Accuracy: 0.688000
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.2056 Validation Accuracy: 0.679800
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.1401 Validation Accuracy: 0.686400
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.2181 Validation Accuracy: 0.689400
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.1874 Validation Accuracy: 0.684400
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.1831 Validation Accuracy: 0.674000
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.2269 Validation Accuracy: 0.676400
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.1662 Validation Accuracy: 0.676000
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.2200 Validation Accuracy: 0.693400
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.1874 Validation Accuracy: 0.683400
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.1605 Validation Accuracy: 0.685600
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.1817 Validation Accuracy: 0.685000
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.1735 Validation Accuracy: 0.683400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.2109 Validation Accuracy: 0.689400
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.1864 Validation Accuracy: 0.686600
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.1764 Validation Accuracy: 0.681400
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.1940 Validation Accuracy: 0.680800
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.1690 Validation Accuracy: 0.675800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.2140 Validation Accuracy: 0.686600
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.1944 Validation Accuracy: 0.687600
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.1695 Validation Accuracy: 0.680400
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.1999 Validation Accuracy: 0.678800
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.1487 Validation Accuracy: 0.679400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.2286 Validation Accuracy: 0.687400
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.1766 Validation Accuracy: 0.688600
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.1743 Validation Accuracy: 0.681600
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.1841 Validation Accuracy: 0.678000
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.1285 Validation Accuracy: 0.682400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.2112 Validation Accuracy: 0.690200
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.1761 Validation Accuracy: 0.686000
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.1505 Validation Accuracy: 0.676200
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.2034 Validation Accuracy: 0.678800
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.1361 Validation Accuracy: 0.678200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.2163 Validation Accuracy: 0.686800
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.1870 Validation Accuracy: 0.686400
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.1523 Validation Accuracy: 0.680600
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.1919 Validation Accuracy: 0.672200
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.1392 Validation Accuracy: 0.682800
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.2035 Validation Accuracy: 0.688200
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.1969 Validation Accuracy: 0.684000
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.1581 Validation Accuracy: 0.673000
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.1893 Validation Accuracy: 0.673400
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.1396 Validation Accuracy: 0.677800
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.2045 Validation Accuracy: 0.685200
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.1679 Validation Accuracy: 0.693000
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.1485 Validation Accuracy: 0.681400
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.1684 Validation Accuracy: 0.677000
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.1185 Validation Accuracy: 0.685800
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.1941 Validation Accuracy: 0.686200
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.1467 Validation Accuracy: 0.691400
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.1413 Validation Accuracy: 0.684400
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.1622 Validation Accuracy: 0.681000
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.1337 Validation Accuracy: 0.679000
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.2050 Validation Accuracy: 0.689600
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.1552 Validation Accuracy: 0.688600
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.1567 Validation Accuracy: 0.682800
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.1712 Validation Accuracy: 0.676400
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.1228 Validation Accuracy: 0.686800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.2078 Validation Accuracy: 0.686400
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.1526 Validation Accuracy: 0.683800
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.1478 Validation Accuracy: 0.675400
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.1715 Validation Accuracy: 0.669600
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.1423 Validation Accuracy: 0.673200
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.2063 Validation Accuracy: 0.678800
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.1570 Validation Accuracy: 0.686600
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.1456 Validation Accuracy: 0.674200
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.1566 Validation Accuracy: 0.673000
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.1216 Validation Accuracy: 0.681400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.2017 Validation Accuracy: 0.683400
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.1605 Validation Accuracy: 0.684000
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.1248 Validation Accuracy: 0.683800
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.1771 Validation Accuracy: 0.665800
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.1152 Validation Accuracy: 0.679600
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.2023 Validation Accuracy: 0.678800
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.1446 Validation Accuracy: 0.688000
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.1435 Validation Accuracy: 0.671800
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.1709 Validation Accuracy: 0.668600
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.1152 Validation Accuracy: 0.683000
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.1985 Validation Accuracy: 0.678200
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.1800 Validation Accuracy: 0.678800
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.1413 Validation Accuracy: 0.676200
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.1521 Validation Accuracy: 0.679800
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.1275 Validation Accuracy: 0.679400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.1787 Validation Accuracy: 0.680800
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.1497 Validation Accuracy: 0.684600
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.1355 Validation Accuracy: 0.669600
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.1484 Validation Accuracy: 0.669800
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.1245 Validation Accuracy: 0.675800
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.1864 Validation Accuracy: 0.679400
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.1407 Validation Accuracy: 0.688800
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.1238 Validation Accuracy: 0.673400
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.1654 Validation Accuracy: 0.664800
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.1214 Validation Accuracy: 0.675800
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.1803 Validation Accuracy: 0.684400
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.1408 Validation Accuracy: 0.679400
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.1435 Validation Accuracy: 0.678200
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.1554 Validation Accuracy: 0.675000
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.1231 Validation Accuracy: 0.673800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.1779 Validation Accuracy: 0.671400
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.1496 Validation Accuracy: 0.680600
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.1403 Validation Accuracy: 0.661600
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.1605 Validation Accuracy: 0.665800
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.1300 Validation Accuracy: 0.684400
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.2083 Validation Accuracy: 0.684200
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.1496 Validation Accuracy: 0.680400
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.1427 Validation Accuracy: 0.666400
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.1757 Validation Accuracy: 0.662200
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.1159 Validation Accuracy: 0.678800
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.1791 Validation Accuracy: 0.687000
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.1265 Validation Accuracy: 0.687800
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.1079 Validation Accuracy: 0.674200
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.1651 Validation Accuracy: 0.662600
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.1394 Validation Accuracy: 0.671600
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.1887 Validation Accuracy: 0.678000
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.1366 Validation Accuracy: 0.685000
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.1243 Validation Accuracy: 0.677000
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.1606 Validation Accuracy: 0.667000
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.1267 Validation Accuracy: 0.678400
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.1744 Validation Accuracy: 0.677800
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.1326 Validation Accuracy: 0.689000
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.1296 Validation Accuracy: 0.676000
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.1595 Validation Accuracy: 0.658000
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.1254 Validation Accuracy: 0.681600
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.1722 Validation Accuracy: 0.682800
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.1301 Validation Accuracy: 0.680000
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.1336 Validation Accuracy: 0.670400
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.1735 Validation Accuracy: 0.663000
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.1311 Validation Accuracy: 0.681600

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6683823585510253

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
